# %%
import requests
import time 
import pandas as pd
 
from bs4 import BeautifulSoup

# %%
url = "https://www.ss.com/en/agriculture/agricultural-machinery/tractors/"
url
# Out:
# 'https://www.ss.com/en/agriculture/agricultural-machinery/tractors/'

# %%
req = requests.get(url) 
req.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(req.text, 'lxml') 

soup.title
# Out:
# <title>SS.COM Agricultural machinery - Tractors, Prices - Advertisements</title>

# %%
def getColList(soup):
    column_list = ["description","url"] 
    headline = soup.find("tr", {"id":"head_line"})
    headtds = headline.find_all("td")
    headcolumns = [el.text for el in headtds[1:]] 
    column_list += headcolumns
    return column_list

# %%
column_names = getColList(soup)
column_names
# Out:
# ['description', 'url', 'Brand', 'Year', 'Price']

# %%
def getRowList(soup):
    trows = soup.find_all('tr')
    aprows = [row for row in trows if row.get('id',"").startswith("tr_") and not row.get('id',"").startswith("tr_bnr") ]
    return aprows

# %%
def getRow(row, colist=column_names):
    row_tds = row.find_all('td')
    rowDict = {}
    if len(row_tds) < 3: # a little sanity check
        print("Hmm bad row")
        return rowDict
    
    rowDict[colist[0]] = row_tds[2].text # so the big assumption is that we always get description in 3rd column
    rowDict[colist[1]] = "https://ss.com" + row_tds[1].find('a').get('href')
    for td,key in zip(row_tds[3:],colist[2:]): 
        rowDict[key] = td.text
    return rowDict

# %%
def getRows(rowlist,colist=column_names):
    return [getRow(row, colist=colist) for row in rowlist]

# %%
def getDFfromURL(url):
    
    req = requests.get(url)
    if req.status_code != 200:
        print("Request Fail with", req.status_code)
        return None 
    soup = BeautifulSoup(req.text, 'lxml')
    column_names = getColList(soup)
    rowlist = getRowList(soup)
    rows = getRows(rowlist,colist=column_names)
    return pd.DataFrame(rows, columns=column_names)

# %%
tractors = "https://www.ss.com/en/agriculture/agricultural-machinery/tractors/"
idf = getDFfromURL(tractors)
idf.head()
# Out:
#                                          description  \
# 0  Transporta pakalpojumi līdz 8 t. Hidrauliski n...
# 1  Nopirkšu mazlietotu traktoru T16 MG originālā ...
# 2  Pārdod Volvo BM frontālo iekrāvēju ar kausu 2m...
# 3  Fastraks 14t pašmassa. Atrums pa ceļõu 80 km ....
# 4  Netto cena 25000 Eur. \r\nPārdodu ļoti labu tr...
#
#                                                  url               Brand  \
# 0  https://ss.com/msg/en/agriculture/agricultural...                   -
# 1  https://ss.com/msg/en/agriculture/agricultural...          T16MgT16Mg
# 2  https://ss.com/msg/en/agriculture/agricultural...  VolvoBm frontalais
# 3  https://ss.com/msg/en/agriculture/agricultural...             Jsb7270
# 4  https://ss.com/msg/en/agriculture/agricultural...           CaseMx135
#
#    Year      Price
# 0     -      30  €
# 1     -       buy
# 2     -   6,500  €
# 3  2012  60,000  €
# 4  2000  30,250  €

# %%
# encode data to utf-8
idf.to_csv("tractors.csv", encoding="utf-8")
# idf.to_csv("traktoru_pardosana.csv")  # ... and here I get error in opening the created .csv file and as a result error for the further step

# %%
traktori = pd.read_csv('tractors.csv')
traktori
# Out:
#     Unnamed: 0                                        description  \
# 0            0  Transporta pakalpojumi līdz 8 t. Hidrauliski n...
# 1            1  Nopirkšu mazlietotu traktoru T16 MG originālā ...
# 19  https://ss.com/msg/en/agriculture/agricultural...
# 20  https://ss.com/msg/en/agriculture/agricultural...
# 21  https://ss.com/msg/en/agriculture/agricultural...
# 22  https://ss.com/msg/en/agriculture/agricultural...
# 23  https://ss.com/msg/en/agriculture/agricultural...
# 24  https://ss.com/msg/en/agriculture/agricultural...
# 25  https://ss.com/msg/en/agriculture/agricultural...
# 26  https://ss.com/msg/en/agriculture/agricultural...
# 27  https://ss.com/msg/en/agriculture/agricultural...
# 28  https://ss.com/msg/en/agriculture/agricultural...
# 29  https://ss.com/msg/en/agriculture/agricultural...
#
#                       Brand  Year      Price
# 0                         -     -      30  €
# 1                T16MgT16Mg     -       buy
# 2        VolvoBm frontalais     -   6,500  €
# 3                   Jsb7270  2012  60,000  €
# 4                 CaseMx135  2000  30,250  €
# 5              KirovecK-701  1991   8,349  €
# 6                ValtraT151  2009  42,350  €
# 7                BelarusMtz  1995   2,500  €
# 8                BelarusMtz  1992   2,250  €
# 9          KravuPārvadājumi     -       1  €
# 10           CaseMagnum 335  2010  54,450  €
# 11                   T25T25     -   3,550  €
# 12                   T25T25     -   3,800  €
# 13     PaštaisitsPastaisits  1995     400  €
# 14          Mtz80 uk, 82 uk     -       buy
# 15                 Mtz jumz     -       buy
# 16                    Mtz80  1989   3,200  €
# 17                    Mtz80  1984   2,800  €
# 18               T-25Mtz 50  2021      70  €
# 19               T40AmT40Am  1982   1,999  €
# 20                 T40amT40     -       buy
# 21  TransportesanaПеревозка     -      35  €
# 22              YanmarKe 4d  1992   4,550  €
# 23             Vtz 25Vtz 25     -          -
# 24             Mtz 82Mtz 82  1988   6,100  €
# 25                  Fiat120  2007   5,500  €
# 26           John Deere7920  2006  32,500  €
# 27               Valtra6800  1996  21,000  €
# 28                    Mtz80  1990   4,800  €
# 29            TyriCxd-188-2     -   36.30  €

# %%
skis = "https://www.ss.com/lv/entertainment/sports/ski/skis/sell/filter/riga_f/fDgSeF4QEFF8FQ==.html"
idf = getDFfromURL(skis)
idf.head()
# Out:
#                                          description  \
# 0  Pilnīgi jaunas, iegādāties var Rīgas centrā. A...
# 1  Pārdodu ļoti labā stāvoklī freestyle slēpes K2...
# 2  В комплекте ботинки Salomon размер 44-45, палк...
# 3  Pārdod Fischer The Curv (2017 g. , 178cm/sidec...
# 4  Pussezonu brauktas Fis slaloma slēpes. \r\nGar...
#
#                                                  url Ražotājs     Modelis  \
# 0  https://ss.com/msg/lv/entertainment/sports/ski...  Salomon         Xdr
# 1  https://ss.com/msg/lv/entertainment/sports/ski...       K2      Domain
# 2  https://ss.com/msg/lv/entertainment/sports/ski...     Head     Extreme
# 3  https://ss.com/msg/lv/entertainment/sports/ski...  Fischer    The Curv
# 4  https://ss.com/msg/lv/entertainment/sports/ski...   Atomic  Redster S9
#
#    Gads Garums    Stāv.    Cena
# 0  2021    160    jaun.  220  €
# 1  2012    174  lietota  300  €
# 2  2010    150  lietota   50  €
# 3  2017    178  lietota  250  €
# 4  2022    165  lietota  700  €

# %%
idf.shape
# Out:
# (30, 8)
